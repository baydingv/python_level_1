# %%
# Все задачи текущего блока решите с помощью генераторов списков!
import random
# Задание-1:
# Дан список, заполненный произвольными целыми числами.
# Получить новый список, элементы которого будут
# квадратами элементов исходного списка
# [1, 2, 4, 0] --> [1, 4, 16, 0]
lst1 = []
for _ in range(30):
    lst1.append(random.randint(-10,10))
lst2 = [x*x for x in lst1]

print(lst1)
print(lst2)
# Out:
# [-9, -2, 5, -6, 9, 10, -9, -10, -9, -7, 10, 9, 3, -10, 4, 3, 10, -5, -3, -8, 6, -4, -1, -3, 5, 6, -4, -1, -4, 4]
# [81, 4, 25, 36, 81, 100, 81, 100, 81, 49, 100, 81, 9, 100, 16, 9, 100, 25, 9, 64, 36, 16, 1, 9, 25, 36, 16, 1, 16, 16]

# %%
# Задание-2:
# Даны два списка фруктов.
# Получить список фруктов, присутствующих в обоих исходных списках.

lst1 =['Яблоко','Груша','Персик','Слива']
lst2 =['Маракуйя','Яблоко','Слива','Вишня','Слива']
lst3 =[x for x in lst1 if x in lst2]
print(lst1)
print(lst2)
print(lst3)
# Out:
# ['Яблоко', 'Груша', 'Персик', 'Слива']
# ['Маракуйя', 'Яблоко', 'Слива', 'Вишня', 'Слива']
# ['Яблоко', 'Слива']

# %%
# Задание-3:
# Дан список, заполненный произвольными числами.
# Получить список из элементов исходного, удовлетворяющих следующим условиям:
# + Элемент кратен 3
# + Элемент положительный
# + Элемент не кратен 4
lst1 = []
for _ in range(300):
    lst1.append(random.randint(24,36))
lst2 =[x for x in lst1 if x%3==0 and x>0 and x%4 !=0]
print(lst1)
print(lst2)
# Out:
# [31, 35, 35, 32, 24, 28, 35, 25, 24, 31, 36, 26, 34, 28, 24, 28, 27, 34, 34, 31, 31, 31, 31, 33, 29, 31, 26, 30, 28, 25, 28, 32, 36, 30, 25, 34, 26, 31, 25, 29, 33, 25, 29, 26, 30, 25, 25, 33, 24, 32, 32, 36, 33, 26, 30, 34, 32, 30, 30, 28, 33, 35, 28, 34, 27, 33, 29, 25, 36, 36, 24, 30, 31, 31, 31, 35, 24, 34, 28, 32, 27, 34, 36, 30, 36, 30, 29, 31, 35, 26, 25, 30, 34, 34, 24, 30, 32, 27, 36, 27, 35, 24, 24, 31, 28, 29, 35, 35, 28, 26, 28, 27, 29, 26, 36, 26, 26, 34, 32, 32, 36, 35, 36, 33, 34, 34, 31, 35, 31, 27, 36, 36, 33, 26, 24, 33, 35, 34, 30, 28, 34, 34, 35, 35, 25, 28, 35, 24, 25, 33, 25, 27, 31, 24, 36, 27, 27, 30, 27, 34, 31, 36, 24, 33, 29, 30, 25, 33, 28, 27, 31, 33, 30, 34, 33, 34, 26, 34, 29, 35, 36, 29, 35, 25, 32, 26, 28, 24, 27, 27, 24, 25, 31, 30, 32, 33, 26, 28, 26, 31, 32, 32, 34, 29, 36, 24, 30, 30, 34, 34, 35, 32, 30, 24, 29, 29, 29, 30, 36, 33, 28, 35, 30, 24, 34, 25, 35, 24, 32, 33, 24, 27, 26, 26, 30, 35, 25, 35, 32, 26, 24, 26, 33, 28, 24, 36, 33, 32, 28, 3
# ...
